# %%
pip install pytidycensus
# Out:
# Collecting pytidycensus
#   Downloading pytidycensus-1.2.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (2.2.2)
# Requirement already satisfied: requests>=2.25.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (2.32.3)
# Requirement already satisfied: geopandas>=0.10.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (1.0.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (2.0.5)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (3.6.1)
# Collecting us>=2.0.0 (from pytidycensus)
#   Downloading us-3.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tqdm>=4.60.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (4.66.5)
# Requirement already satisfied: appdirs>=1.4.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (1.4.4)
# Requirement already satisfied: certifi>=2025.8.3 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (2025.8.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (1.26.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (6.0.1)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (3.9.2)
# Requirement already satisfied: pygris>=0.2.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pytidycensus) (0.2.0)
# Collecting tobler>=0.12.1 (from pytidycensus)
#   Downloading tobler-0.12.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from geopandas>=0.10.0->pytidycensus) (0.10.0)
# Requirement already satisfied: packaging in c:\users\olubl\appdata\roaming\python\python312\site-packages (from geopandas>=0.10.0->pytidycensus) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from matplotlib>=3.5.0->pytidycensus) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from matplotlib>=3.5.0->pytidycensus) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from matplotlib>=3.5.0->pytidycensus) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from matplotlib>=3.5.0->pytidycensus) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from matplotlib>=3.5.0->pytidycensus) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from matplotlib>=3.5.0->pytidycensus) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\olubl\appdata\roaming\python\python312\site-packages (from matplotlib>=3.5.0->pytidycensus) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pandas>=1.2.0->pytidycensus) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from pandas>=1.2.0->pytidycensus) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from requests>=2.25.0->pytidycensus) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from requests>=2.25.0->pytidycensus) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from requests>=2.25.0->pytidycensus) (2.2.3)
# Collecting rasterio (from tobler>=0.12.1->pytidycensus)
#   Downloading rasterio-1.4.3-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: scipy in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from tobler>=0.12.1->pytidycensus) (1.13.1)
# Requirement already satisfied: statsmodels in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from tobler>=0.12.1->pytidycensus) (0.14.2)
# Collecting rasterstats (from tobler>=0.12.1->pytidycensus)
#   Downloading rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: libpysal in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from tobler>=0.12.1->pytidycensus) (4.13.0)
# Requirement already satisfied: joblib in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from tobler>=0.12.1->pytidycensus) (1.4.2)
# Requirement already satisfied: colorama in c:\users\olubl\appdata\roaming\python\python312\site-packages (from tqdm>=4.60.0->pytidycensus) (0.4.6)
# Requirement already satisfied: jellyfish in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from us>=2.0.0->pytidycensus) (1.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\olubl\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->pytidycensus) (1.17.0)
# Requirement already satisfied: beautifulsoup4>=4.10 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from libpysal->tobler>=0.12.1->pytidycensus) (4.12.3)
# Requirement already satisfied: platformdirs>=2.0.2 in c:\users\olubl\appdata\roaming\python\python312\site-packages (from libpysal->tobler>=0.12.1->pytidycensus) (4.3.8)
# Requirement already satisfied: scikit-learn>=1.1 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from libpysal->tobler>=0.12.1->pytidycensus) (1.5.1)
# Collecting affine (from rasterio->tobler>=0.12.1->pytidycensus)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from rasterio->tobler>=0.12.1->pytidycensus) (23.1.0)
# Requirement already satisfied: click>=4.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from rasterio->tobler>=0.12.1->pytidycensus) (8.1.7)
# Collecting cligj>=0.5 (from rasterio->tobler>=0.12.1->pytidycensus)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->tobler>=0.12.1->pytidycensus)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting fiona (from rasterstats->tobler>=0.12.1->pytidycensus)
#   Downloading fiona-1.10.1-cp312-cp312-win_amd64.whl.metadata (58 kB)
# Collecting simplejson (from rasterstats->tobler>=0.12.1->pytidycensus)
#   Downloading simplejson-3.20.2-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from statsmodels->tobler>=0.12.1->pytidycensus) (0.5.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from beautifulsoup4>=4.10->libpysal->tobler>=0.12.1->pytidycensus) (2.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\olubl\anaconda3\envs\spatialdata\lib\site-packages (from scikit-learn>=1.1->libpysal->tobler>=0.12.1->pytidycensus) (3.5.0)
# Downloading pytidycensus-1.2.3-py3-none-any.whl (120 kB)
# Downloading tobler-0.12.1-py3-none-any.whl (28 kB)
# Downloading us-3.2.0-py3-none-any.whl (13 kB)
# Downloading rasterio-1.4.3-cp312-cp312-win_amd64.whl (25.4 MB)
#    ---------------------------------------- 0.0/25.4 MB ? eta -:--:--
#    -------- ------------------------------- 5.5/25.4 MB 25.8 MB/s eta 0:00:01
#    -------------------- ------------------- 12.8/25.4 MB 31.0 MB/s eta 0:00:01
#    --------------------------------- ------ 21.5/25.4 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 25.4/25.4 MB 30.4 MB/s eta 0:00:00
# Downloading rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading fiona-1.10.1-cp312-cp312-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ------------- -------------------------- 8.1/24.5 MB 38.7 MB/s eta 0:00:01
#    --------------------------- ------------ 16.5/24.5 MB 40.0 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.5 MB 39.6 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 32.3 MB/s eta 0:00:00
# Downloading simplejson-3.20.2-cp312-cp312-win_amd64.whl (75 kB)
# Installing collected packages: us, simplejson, affine, cligj, click-plugins, rasterio, fiona, rasterstats, tobler, pytidycensus
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 fiona-1.10.1 pytidycensus-1.2.3 rasterio-1.4.3 rasterstats-0.20.0 simplejson-3.20.2 tobler-0.12.1 us-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import pytidycensus as tc
# Out:
# C:\Users\olubl\AppData\Local\Temp\ipykernel_4996\4052122762.py:5: UserWarning: Mapping functions unavailable due to import error: NameError. To use mapping features, ensure all dependencies are properly installed: pip install pytidycensus[map]
#   import pytidycensus as tc

# %%
tc.set_census_api_key("3d33dd56fa8e81fd42e039aadf43b9676976f27c")

variables = {
    "B01003_001E": "total_population",              
    "B01002_001E": "median_age",                    
    "B02001_002E": "white_alone",                
    "B02001_003E": "black_or_african_american",      
    "B03003_003E": "hispanic_latino",             
    "B19013_001E": "median_household_income",      
    "B15003_022E": "bachelors_degree",               
}

year = 2023
df = tc.get_acs(
    geography="county",
    variables=list(variables.keys()),
    state="NC",
    year=year,
    output="wide",    
    geometry=True  
)

#drop columns for margin of error (not necessary)
moe_cols = [col for col in df.columns if col.endswith("e")]
df = df.drop(columns = moe_cols)


#rename columns from variable key to statistic
df = df.rename(columns={var: name for var, name in variables.items()})
# Out:
# Census API key has been set for this session.
# Getting data from the 2019-2023 5-year ACS

# %%
df
# Out:
#     GEOID                                           geometry  \
# 0   37133  MULTIPOLYGON (((-77.171 34.626, -77.169 34.627...
# 1   37009  POLYGON ((-81.741 36.413, -81.737 36.414, -81....
# 2   37169  POLYGON ((-80.45 36.328, -80.45 36.339, -80.44...
# 3   37053  POLYGON ((-76.313 36.551, -76.313 36.551, -76....
# 4   37173  POLYGON ((-83.949 35.461, -83.943 35.465, -83....
# ..    ...                                                ...
# 95  37061  POLYGON ((-78.199 34.742, -78.198 34.742, -78....
# 96  37003  POLYGON ((-81.344 35.827, -81.338 35.857, -81....
# 97  37027  POLYGON ((-81.811 36.112, -81.78 36.114, -81.6...
# 98  37183  POLYGON ((-78.983 35.644, -78.971 35.676, -78....
# 99  37109  POLYGON ((-81.535 35.568, -81.472 35.566, -81....
#
#             NAMELSAD  total_population  median_age  white_alone  \
# 0      Onslow County            208537        27.1       144394
# 1        Ashe County             26831        49.8        25215
# 2      Stokes County             44889        47.6        40992
# 3   Currituck County             29612        41.7        25360
# 4       Swain County             14065        42.6         8601
# ..               ...               ...         ...          ...
# 95     Duplin County             49053        40.7        28190
# 96  Alexander County             36440        43.8        31804
# 97   Caldwell County             80618        45.5        69846
# 98       Wake County           1151009        37.2       683568
# 99    Lincoln County             90359        44.3        76579
#
#     black_or_african_american  hispanic_latino  median_household_income  \
# 0                       26157            28739                    64568
# 1                         289             1569                    50827
# 2                        1543             1621                    60039
# 3                        1509             1444                    91548
# 4                         212              718                    55429
# ..                        ...              ...                      ...
# 95                      11184            11137                    51880
# 96                       1468             1950                    65268
# 97                       3319             5160                    55401
# 98                     221985           131104                   101763
# 99                       5271             7065                    78490
#
#     bachelors_degree county                              NAME
# 0              20233    133     Onslow County, North Carolina
# 1               2977    009       Ashe County, North Carolina
# 2               4097    169     Stokes County, North Carolina
# 3               4357    053  Currituck County, North Carolina
# 4               1196    173      Swain County, North Carolina
# ..               ...    ...                               ...
# 95              4167    061     Duplin County, North Carolina
# 96              2747    003  Alexander County, North Carolina
# 97              7571    027   Caldwell County, North Carolina
# 98            263970    183       Wake County, North Carolina
# 99             12649    109    Lincoln County, North Carolina
#
# [100 rows x 12 columns]

# %%
df.plot()
# Out:
# <Axes: >
